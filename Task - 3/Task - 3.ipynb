# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r"C:\Users\mades\Downloads\archive (24)\House Price India.csv")
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810635  42491                   4                 2.50
# 1      6762810998  42491                   5                 2.75
# 2      6762812605  42491                   4                 2.50
# 3      6762812919  42491                   3                 2.00
# 4      6762813105  42491                   3                 2.50
# ...           ...    ...                 ...                  ...
# 14614  6762830250  42734                   2                 1.50
# 14615  6762830339  42734                   3                 2.00
# 14616  6762830618  42734                   2                 1.00
# 14617  6762830709  42734                   4                 1.00
# 14618  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             2920      4000               1.5                   0
# ...

# %%
df.isna().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14619 entries, 0 to 14618
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14619 non-null  int64
#  1   Date                                   14619 non-null  int64
#  2   number of bedrooms                     14619 non-null  int64
#  3   number of bathrooms                    14619 non-null  float64
#  4   living area                            14619 non-null  int64
#  5   lot area                               14619 non-null  int64
#  6   number of floors                       14619 non-null  float64
#  7   waterfront present                     14619 non-null  int64
#  8   number of views                        14619 non-null  int64
#  9   condition of the house                 14619 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.461900e+04  14619.000000        14619.000000         14619.000000
# mean   6.762821e+09  42604.546412            3.379233             2.129557
# std    6.237162e+03     67.343747            0.938655             0.769955
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14619.000000  1.461900e+04      14619.000000        14619.000000
# mean    2098.156851  1.509369e+04          1.502326            0.007661
# std      928.218740  3.792089e+04          0.540241            0.087196
# ...

# %%
x = df.drop(['Price','Date','id'], axis = 1)
y = df['Price']

# %%
x
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 0                       4                 2.50         2920      4000
# 1                       5                 2.75         2910      9480
# 2                       4                 2.50         3310     42998
# 3                       3                 2.00         2710      4500
# 4                       3                 2.50         2600      4750
# ...                   ...                  ...          ...       ...
# 14614                   2                 1.50         1556     20000
# 14615                   3                 2.00         1680      7000
# 14616                   2                 1.00         1070      6120
# 14617                   4                 1.00         1030      6621
# 14618                   3                 1.00          900      4770
#
#        number of floors  waterfront present  number of views  \
# 0                   1.5                   0                0
# ...

# %%
y
# Out:
# 0        1400000
# 1        1200000
# 2         838000
# 3         805000
# 4         790000
#           ...
# 14614     221700
# 14615     219200
# 14616     209000
# 14617     205000
# 14618     146000
# Name: Price, Length: 14619, dtype: int64

# %%
x_train,x_test, y_train,y_test = train_test_split(x,y, test_size=0.3,random_state=234)

# %%
x_train.shape
# Out:
# (10233, 20)

# %%
y_train.shape
# Out:
# (10233,)

# %%
linear_model = LinearRegression()
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_pred = linear_model.predict(x_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae}, MSE: {mse}, R^2: {r2}")
# Out:
# MAE: 124003.2174985549, MSE: 34125901933.034462, R^2: 0.7123542029260718

# %%
from sklearn.ensemble import RandomForestRegressor
RF_model = RandomForestRegressor()
RF_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_pred = RF_model.predict(x_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae}, MSE: {mse}, R^2: {r2}")
# Out:
# MAE: 68786.91672138624, MSE: 17549587295.66402, R^2: 0.852075264241056

# %% [raw]
# Compare to LinearRegression and RandomForest models LinearRegression model is best, that why to choose this LinearRegression model.

# %%
import joblib
joblib.dump(linear_model, 'house_price_model.pkl')
# Out:
# ['house_price_model.pkl']

# %%
# !streamlit run House_price_prediction.py
