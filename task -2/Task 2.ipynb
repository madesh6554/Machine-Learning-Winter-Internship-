# %% [markdown]
# # Task - 2
# ## Linear Regression Task

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import  mean_squared_error, r2_score

# %% [markdown]
# ## Dataset using Indian House Pries:

# %%
df = pd.read_csv(r"C:\Users\mades\Downloads\House Price India\House Price India.csv")
df.head()
# Out:
#            id   Date  number of bedrooms  ...  Number of schools nearby  Distance from the airport    Price
# 0  6762810635  42491                   4  ...                         2                         51  1400000
# 1  6762810998  42491                   5  ...                         1                         53  1200000
# 2  6762812605  42491                   4  ...                         3                         76   838000
# 3  6762812919  42491                   3  ...                         1                         51   805000
# 4  6762813105  42491                   3  ...                         1                         67   790000
#
# [5 rows x 23 columns]

# %%
df.isna().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14619 entries, 0 to 14618
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14619 non-null  int64
#  1   Date                                   14619 non-null  int64
#  2   number of bedrooms                     14619 non-null  int64
#  3   number of bathrooms                    14619 non-null  float64
#  4   living area                            14619 non-null  int64
#  5   lot area                               14619 non-null  int64
#  6   number of floors                       14619 non-null  float64
#  7   waterfront present                     14619 non-null  int64
#  8   number of views                        14619 non-null  int64
#  9   condition of the house                 14619 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id          Date  ...  Distance from the airport         Price
# count  1.461900e+04  14619.000000  ...               14619.000000  1.461900e+04
# mean   6.762821e+09  42604.546412  ...                  64.951433  5.388063e+05
# std    6.237162e+03     67.343747  ...                   8.936129  3.672294e+05
# min    6.762810e+09  42491.000000  ...                  50.000000  7.800000e+04
# 25%    6.762815e+09  42546.000000  ...                  57.000000  3.200000e+05
# 50%    6.762821e+09  42600.000000  ...                  65.000000  4.500000e+05
# 75%    6.762826e+09  42662.000000  ...                  73.000000  6.450000e+05
# max    6.762832e+09  42734.000000  ...                  80.000000  7.700000e+06
#
# [8 rows x 23 columns]

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.plot(df['Price'])

# %% [markdown]
# ## Split the dataset into training and testing sets

# %%
x = df.drop(['Price'],axis=1)

# %%
y = df['Price']

# %%
x
# Out:
#                id   Date  number of bedrooms  ...  lot_area_renov  Number of schools nearby  Distance from the airport
# 0      6762810635  42491                   4  ...            4000                         2                         51
# 1      6762810998  42491                   5  ...            6600                         1                         53
# 2      6762812605  42491                   4  ...           42847                         3                         76
# 3      6762812919  42491                   3  ...            4500                         1                         51
# 4      6762813105  42491                   3  ...            4750                         1                         67
# ...           ...    ...                 ...  ...             ...                       ...                        ...
# 14614  6762830250  42734                   2  ...           17286                         3                         76
# ...

# %%
y
# Out:
# 0        1400000
# 1        1200000
# 2         838000
# 3         805000
# 4         790000
#           ...
# 14614     221700
# 14615     219200
# 14616     209000
# 14617     205000
# 14618     146000
# Name: Price, Length: 14619, dtype: int64

# %%
x_train,x_test, y_train,y_test = train_test_split(x,y, test_size=0.3, random_state=222)

# %% [markdown]
# ## Train the Linear Regression model

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Make predictions

# %%
prediction=model.predict(x_test)
prediction
# Out:
# array([378777.52597046, 661627.60968018, 323912.21987915, ...,
#        857230.22283936, 457784.35391235, 468113.61315918])

# %%
data_point = np.array([[6762830250, 42734, 2, 1.50, 1556, 20000, 1.0, 0, 0, 4, 7, 1556, 0, 1957, 0, 122066, 52.6191, -114.472, 2250, 17286, 3, 76]])
model.predict(data_point)
# Out:
# C:\Users\mades\anaconda3\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([262603.11193848])

# %% [markdown]
# ## Evaluate the model

# %%
mse = mean_squared_error(y_test, prediction)
r2 = mean_squared_error(y_test, prediction)
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 34004479695.798836
# R-squared: 34004479695.798836

# %%
model.intercept_
# Out:
# 153879544259.66467

# %%
model.coef_
# Out:
# array([-2.27743387e+01, -4.52681156e+00, -3.42706208e+04,  2.87813822e+04,
#         9.80490816e+01, -2.50419299e-01, -2.21587957e+04,  4.42662560e+05,
#         4.08264320e+04,  1.32797617e+04,  5.45196373e+04,  7.36193538e+01,
#         2.44297278e+01, -1.65531188e+03,  1.08061220e+01,  1.00690429e+03,
#         1.75592141e+05, -9.09848922e+04, -2.64604039e+01, -2.20585386e-01,
#         3.05622186e+02, -1.65712335e+02])

# %% [markdown]
# ## Visualize the regression line with data points

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have y_actual and y_predicted
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=prediction)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs. Predicted Values')
plt.show()

# %%
sns.pairplot(data=df, x_vars=['grade of the house', 'Area of the house(excluding basement)'], y_vars='Price', kind='reg', height=5)
plt.show()
